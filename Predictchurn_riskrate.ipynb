# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
train=pd.read_csv('D:/New folder/dataset/train.csv')

# %%
train.head()
# Out:
#                             customer_id              Name  age gender  \
# 0      fffe4300490044003600300030003800   Pattie Morrisey   18      F
# 1  fffe43004900440032003100300035003700       Traci Peery   32      F
# 2      fffe4300490044003100390032003600   Merideth Mcmeen   44      F
# 3  fffe43004900440036003000330031003600  Eufemia Cardwell   37      M
# 4  fffe43004900440031003900350030003600      Meghan Kosak   31      F
#
#   security_no region_category  membership_category joining_date  \
# 0     XW0DQ7H         Village  Platinum Membership   2017-08-17
# 1     5K0N3X1            City   Premium Membership   2017-08-28
# 2     1F2TCL3            Town        No Membership   2016-11-11
# 3     VJGJ33N            City        No Membership   2016-10-29
# 4     SVZXCWB            City        No Membership   2017-09-12
#
#   joined_through_referral referral_id  ... avg_time_spent  \
# 0                      No    xxxxxxxx  ...         300.63
# ...

# %%
train.tail()
# Out:
#                                 customer_id              Name  age gender  \
# 36987  fffe43004900440035003500390036003100          Cuc Tarr   46      F
# 36988  fffe43004900440033003500380036003600    Jenni Stronach   29      F
# 36989      fffe4300490044003500330034003100     Luciana Kinch   23      F
# 36990  fffe43004900440031003200390039003000     Tawana Ardoin   53      M
# 36991  fffe43004900440033003600340034003200  Verlene Beaulieu   35      M
#
#       security_no region_category  membership_category joining_date  \
# 36987     6F51HFO             NaN     Basic Membership   2017-09-21
# 36988     21KSM8Y            Town     Basic Membership   2016-06-27
# 36989     XK1IM9H             NaN     Basic Membership   2016-09-11
# 36990     K6VTP1Z         Village  Platinum Membership   2017-06-15
# 36991     LBX0GLR            Town    Silver Membership   2015-10-23
#
#       joined_through_referral referral_id  ... avg_time_spent  \
# ...

# %%
train.shape
# Out:
# (36992, 25)

# %%
train.columns
# Out:
# Index(['customer_id', 'Name', 'age', 'gender', 'security_no',
#        'region_category', 'membership_category', 'joining_date',
#        'joined_through_referral', 'referral_id', 'preferred_offer_types',
#        'medium_of_operation', 'internet_option', 'last_visit_time',
#        'days_since_last_login', 'avg_time_spent', 'avg_transaction_value',
#        'avg_frequency_login_days', 'points_in_wallet', 'used_special_discount',
#        'offer_application_preference', 'past_complaint', 'complaint_status',
#        'feedback', 'churn_risk_score'],
#       dtype='object')

# %%
train.isnull().sum()
# Out:
# customer_id                        0
# Name                               0
# age                                0
# gender                             0
# security_no                        0
# region_category                 5428
# membership_category                0
# joining_date                       0
# joined_through_referral            0
# referral_id                        0
# preferred_offer_types            288
# medium_of_operation                0
# internet_option                    0
# last_visit_time                    0
# days_since_last_login              0
# avg_time_spent                     0
# avg_transaction_value              0
# avg_frequency_login_days           0
# points_in_wallet                3443
# used_special_discount              0
# offer_application_preference       0
# past_complaint                     0
# complaint_status                   0
# feedback                           0
# churn_risk_score                   0
# dtype: int64

# %%
pd.DataFrame(round(train.isnull().sum()/train.shape[0]*100,3),columns=['null values%'])
# Out:
#                               null values%
# customer_id                          0.000
# Name                                 0.000
# age                                  0.000
# gender                               0.000
# security_no                          0.000
# region_category                     14.673
# membership_category                  0.000
# joining_date                         0.000
# joined_through_referral              0.000
# referral_id                          0.000
# preferred_offer_types                0.779
# medium_of_operation                  0.000
# internet_option                      0.000
# last_visit_time                      0.000
# days_since_last_login                0.000
# avg_time_spent                       0.000
# avg_transaction_value                0.000
# avg_frequency_login_days             0.000
# points_in_wallet                     9.307
# used_special_discount                0.000
# offer_application_preference         0.000
# ...

# %%
train.nunique()
# Out:
# customer_id                     36992
# Name                            36992
# age                                55
# gender                              3
# security_no                     36992
# region_category                     3
# membership_category                 6
# joining_date                     1096
# joined_through_referral             3
# referral_id                     11359
# preferred_offer_types               3
# medium_of_operation                 4
# internet_option                     3
# last_visit_time                 30101
# days_since_last_login              27
# avg_time_spent                  25961
# avg_transaction_value           36894
# avg_frequency_login_days         1654
# points_in_wallet                23699
# used_special_discount               2
# offer_application_preference        2
# past_complaint                      2
# complaint_status                    5
# feedback                            9
# churn_risk_score                    6
# ...

# %%
train.gender.unique()
# Out:
# array(['F', 'M', 'Unknown'], dtype=object)

# %%
train.region_category.unique()
# Out:
# array(['Village', 'City', 'Town', nan], dtype=object)

# %%
train.membership_category.unique()
# Out:
# array(['Platinum Membership', 'Premium Membership', 'No Membership',
#        'Gold Membership', 'Silver Membership', 'Basic Membership'],
#       dtype=object)

# %%
train.joined_through_referral.unique()
# Out:
# array(['No', '?', 'Yes'], dtype=object)

# %%
train.joined_through_referral.value_counts()
# Out:
# No     15839
# Yes    15715
# ?       5438
# Name: joined_through_referral, dtype: int64

# %%
train.preferred_offer_types.unique()
# Out:
# array(['Gift Vouchers/Coupons', 'Credit/Debit Card Offers',
#        'Without Offers', nan], dtype=object)

# %%
train.medium_of_operation.unique()
# Out:
# array(['?', 'Desktop', 'Smartphone', 'Both'], dtype=object)

# %%
train.internet_option.unique()
# Out:
# array(['Wi-Fi', 'Mobile_Data', 'Fiber_Optic'], dtype=object)

# %%
train.days_since_last_login.unique()
# Out:
# array([  17,   16,   14,   11,   20,   23,   10,   19,   15,   13, -999,
#           5,   12,    9,   21,   18,    1,   22,    4,    8,    3,    6,
#           2,   24,    7,   26,   25], dtype=int64)

# %%
train.days_since_last_login.value_counts()
# Out:
#  12     2380
#  13     2373
#  14     2307
#  15     2278
#  11     2262
#  10     2091
#  16     2068
# -999    1999
#  9      1863
#  17     1747
#  8      1571
#  18     1444
#  7      1442
#  19     1308
#  6      1257
#  5      1234
#  20     1184
#  21     1015
#  4       998
#  22      895
#  3       852
#  23      727
#  2       613
#  24      471
#  1       328
#  25      203
#  26       82
# Name: days_since_last_login, dtype: int64

# %%
train.used_special_discount.unique()
# Out:
# array(['Yes', 'No'], dtype=object)

# %%
train.offer_application_preference.unique()
# Out:
# array(['Yes', 'No'], dtype=object)

# %%
train.past_complaint.unique()
# Out:
# array(['No', 'Yes'], dtype=object)

# %%
train.complaint_status.unique()
# Out:
# array(['Not Applicable', 'Solved', 'Solved in Follow-up', 'Unsolved',
#        'No Information Available'], dtype=object)

# %%
train.feedback.unique()
# Out:
# array(['Products always in Stock', 'Quality Customer Care',
#        'Poor Website', 'No reason specified', 'Poor Product Quality',
#        'Poor Customer Service', 'Too many ads', 'User Friendly Website',
#        'Reasonable Price'], dtype=object)

# %%
train.churn_risk_score.unique()
# Out:
# array([ 2,  1,  5,  3,  4, -1], dtype=int64)

# %%
train.churn_risk_score.value_counts()
# Out:
#  3    10424
#  4    10185
#  5     9827
#  2     2741
#  1     2652
# -1     1163
# Name: churn_risk_score, dtype: int64

# %%
train.replace('?',np.NaN,inplace=True)

# %%
train.isnull().sum()
# Out:
# customer_id                        0
# Name                               0
# age                                0
# gender                             0
# security_no                        0
# region_category                 5428
# membership_category                0
# joining_date                       0
# joined_through_referral         5438
# referral_id                        0
# preferred_offer_types            288
# medium_of_operation             5393
# internet_option                    0
# last_visit_time                    0
# days_since_last_login              0
# avg_time_spent                     0
# avg_transaction_value              0
# avg_frequency_login_days           0
# points_in_wallet                3443
# used_special_discount              0
# offer_application_preference       0
# past_complaint                     0
# complaint_status                   0
# feedback                           0
# churn_risk_score                   0
# dtype: int64

# %%
train[train['region_category'].isnull()].index.tolist()
# Out:
# [7,
#  32,
#  37,
#  61,
#  64,
#  83,
#  86,
#  96,
#  104,
#  108,
#  115,
#  120,
#  124,
#  127,
#  138,
#  145,
#  164,
#  177,
#  201,
#  208,
#  216,
#  225,
#  243,
#  248,
#  251,
#  252,
#  260,
#  267,
#  274,
#  285,
#  291,
#  293,
#  295,
#  299,
#  302,
#  330,
#  337,
#  340,
#  341,
#  346,
#  353,
#  354,
#  359,
#  361,
#  367,
#  369,
#  374,
#  391,
#  392,
#  396,
#  413,
#  420,
#  427,
#  435,
#  439,
#  447,
#  465,
#  466,
#  477,
#  485,
#  497,
#  511,
#  516,
#  517,
#  520,
#  531,
#  538,
#  548,
#  573,
#  577,
#  585,
#  586,
#  587,
#  603,
#  609,
#  610,
#  614,
#  616,
#  619,
#  627,
#  628,
#  629,
#  636,
#  652,
#  655,
#  660,
#  661,
#  668,
#  690,
#  693,
#  702,
#  721,
#  723,
#  731,
#  735,
#  738,
#  747,
#  754,
#  755,
#  759,
#  760,
#  762,
#  764,
#  782,
#  784,
#  789,
#  799,
#  800,
#  807,
#  808,
#  809,
#  813,
#  832,
#  835,
#  846,
#  860,
#  870,
#  871,
#  874,
#  877,
#  883,
#  888,
#  893,
#  901,
#  924,
#  926,
# ...

# %%
train['region_category'].fillna(method='ffill',axis=0,inplace=True)

# %%
train[train['joined_through_referral'].isnull()].index.tolist()
# Out:
# [1,
#  7,
#  15,
#  28,
#  30,
#  40,
#  42,
#  48,
#  56,
#  58,
#  62,
#  73,
#  76,
#  79,
#  81,
#  86,
#  90,
#  118,
#  125,
#  126,
#  148,
#  151,
#  153,
#  156,
#  160,
#  164,
#  171,
#  183,
#  188,
#  206,
#  214,
#  232,
#  237,
#  241,
#  243,
#  244,
#  253,
#  258,
#  266,
#  273,
#  284,
#  288,
#  290,
#  340,
#  350,
#  354,
#  355,
#  357,
#  371,
#  372,
#  374,
#  377,
#  395,
#  402,
#  403,
#  407,
#  408,
#  411,
#  414,
#  417,
#  422,
#  423,
#  424,
#  430,
#  431,
#  440,
#  443,
#  452,
#  477,
#  479,
#  487,
#  494,
#  499,
#  509,
#  512,
#  531,
#  549,
#  557,
#  562,
#  564,
#  566,
#  569,
#  576,
#  578,
#  580,
#  594,
#  599,
#  600,
#  607,
#  610,
#  619,
#  629,
#  632,
#  652,
#  656,
#  663,
#  667,
#  683,
#  684,
#  692,
#  722,
#  723,
#  729,
#  740,
#  746,
#  750,
#  752,
#  753,
#  756,
#  758,
#  760,
#  789,
#  796,
#  818,
#  824,
#  832,
#  835,
#  842,
#  859,
#  865,
#  870,
#  875,
#  878,
#  880,
#  891,
#  894,
#  899,
# ...

# %%
train['joined_through_referral'].fillna(method='bfill',axis=0,inplace=True)

# %%
train['joined_through_referral'].isnull().sum()
# Out:
# 0

# %%
train[train['preferred_offer_types'].isnull()].index.tolist()
# Out:
# [94,
#  241,
#  417,
#  457,
#  470,
#  505,
#  650,
#  661,
#  663,
#  733,
#  1022,
#  1086,
#  1319,
#  1329,
#  1489,
#  1633,
#  1645,
#  1717,
#  1968,
#  2158,
#  2281,
#  2437,
#  2466,
#  2553,
#  2759,
#  2966,
#  3145,
#  3218,
#  3367,
#  3478,
#  3486,
#  3489,
#  3598,
#  3610,
#  3670,
#  3780,
#  3907,
#  3917,
#  4021,
#  4062,
#  4109,
#  4125,
#  4135,
#  4473,
#  4529,
#  4670,
#  4718,
#  4734,
#  4872,
#  5068,
#  5197,
#  5282,
#  5789,
#  6173,
#  6218,
#  6313,
#  6325,
#  6340,
#  6379,
#  6828,
#  7131,
#  7212,
#  7229,
#  7378,
#  8349,
#  8377,
#  8560,
#  9001,
#  9251,
#  9411,
#  9436,
#  9477,
#  9633,
#  9727,
#  9758,
#  9788,
#  9834,
#  9928,
#  10025,
#  10476,
#  10614,
#  10690,
#  10729,
#  10860,
#  11442,
#  11643,
#  11777,
#  12137,
#  12188,
#  12410,
#  12428,
#  12524,
#  12720,
#  13222,
#  13228,
#  13322,
#  13393,
#  13478,
#  13525,
#  13630,
#  13700,
#  13762,
#  13782,
#  14030,
#  14242,
#  14897,
#  15032,
#  15202,
# ...

# %%
train['preferred_offer_types'].value_counts()
# Out:
# Gift Vouchers/Coupons       12349
# Credit/Debit Card Offers    12274
# Without Offers              12081
# Name: preferred_offer_types, dtype: int64

# %%
train['preferred_offer_types'].fillna(method='ffill',axis=0,inplace=True)

# %%
train['preferred_offer_types'].isnull().sum()
# Out:
# 0

# %%
train[train['medium_of_operation'].isnull()].index.tolist()
# Out:
# [0,
#  5,
#  9,
#  14,
#  16,
#  17,
#  19,
#  22,
#  26,
#  28,
#  29,
#  41,
#  44,
#  50,
#  55,
#  66,
#  68,
#  72,
#  76,
#  78,
#  81,
#  104,
#  122,
#  140,
#  143,
#  148,
#  164,
#  175,
#  176,
#  177,
#  187,
#  194,
#  200,
#  202,
#  215,
#  219,
#  226,
#  228,
#  233,
#  235,
#  236,
#  245,
#  263,
#  266,
#  280,
#  286,
#  300,
#  311,
#  321,
#  336,
#  347,
#  352,
#  353,
#  373,
#  376,
#  378,
#  380,
#  392,
#  397,
#  399,
#  400,
#  403,
#  408,
#  415,
#  416,
#  417,
#  420,
#  432,
#  440,
#  441,
#  442,
#  446,
#  452,
#  468,
#  469,
#  470,
#  476,
#  489,
#  522,
#  530,
#  531,
#  537,
#  538,
#  549,
#  560,
#  571,
#  572,
#  577,
#  581,
#  583,
#  585,
#  592,
#  597,
#  604,
#  616,
#  617,
#  618,
#  630,
#  637,
#  642,
#  646,
#  649,
#  680,
#  687,
#  701,
#  706,
#  707,
#  721,
#  728,
#  729,
#  733,
#  737,
#  741,
#  748,
#  752,
#  760,
#  762,
#  768,
#  771,
#  778,
#  791,
#  793,
#  819,
#  821,
#  829,
#  837,
#  851,
#  863,
# ...

# %%
train['medium_of_operation'].fillna('Both',inplace=True)

# %%
train['medium_of_operation'].isnull().sum()
# Out:
# 0

# %%
sns.distplot(train['points_in_wallet'])
# Out:
# C:\Users\vikas\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='points_in_wallet', ylabel='Density'>

# %%
train['points_in_wallet'].mean()
# Out:
# 686.882198742908

# %%
train['points_in_wallet'].fillna(train['points_in_wallet'].mean(),inplace=True)

# %%
train.isnull().sum()
# Out:
# customer_id                     0
# Name                            0
# age                             0
# gender                          0
# security_no                     0
# region_category                 0
# membership_category             0
# joining_date                    0
# joined_through_referral         0
# referral_id                     0
# preferred_offer_types           0
# medium_of_operation             0
# internet_option                 0
# last_visit_time                 0
# days_since_last_login           0
# avg_time_spent                  0
# avg_transaction_value           0
# avg_frequency_login_days        0
# points_in_wallet                0
# used_special_discount           0
# offer_application_preference    0
# past_complaint                  0
# complaint_status                0
# feedback                        0
# churn_risk_score                0
# dtype: int64

# %%
sns.distplot(train['points_in_wallet'])
# Out:
# C:\Users\vikas\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='points_in_wallet', ylabel='Density'>

# %%
train.head()
# Out:
#                             customer_id              Name  age gender  \
# 0      fffe4300490044003600300030003800   Pattie Morrisey   18      F
# 1  fffe43004900440032003100300035003700       Traci Peery   32      F
# 2      fffe4300490044003100390032003600   Merideth Mcmeen   44      F
# 3  fffe43004900440036003000330031003600  Eufemia Cardwell   37      M
# 4  fffe43004900440031003900350030003600      Meghan Kosak   31      F
#
#   security_no region_category  membership_category joining_date  \
# 0     XW0DQ7H         Village  Platinum Membership   2017-08-17
# 1     5K0N3X1            City   Premium Membership   2017-08-28
# 2     1F2TCL3            Town        No Membership   2016-11-11
# 3     VJGJ33N            City        No Membership   2016-10-29
# 4     SVZXCWB            City        No Membership   2017-09-12
#
#   joined_through_referral referral_id  ... avg_time_spent  \
# 0                      No    xxxxxxxx  ...         300.63
# ...

# %%
sns.distplot(train['age'])
# Out:
# C:\Users\vikas\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='age', ylabel='Density'>

# %%
train.describe()
# Out:
#                 age  days_since_last_login  avg_time_spent  \
# count  36992.000000           36992.000000    36992.000000
# mean      37.118161             -41.915576      243.472334
# std       15.867412             228.819900      398.289149
# min       10.000000            -999.000000    -2814.109110
# 25%       23.000000               8.000000       60.102500
# 50%       37.000000              12.000000      161.765000
# 75%       51.000000              16.000000      356.515000
# max       64.000000              26.000000     3235.578521
#
#        avg_transaction_value  points_in_wallet  churn_risk_score
# count           36992.000000      36992.000000      36992.000000
# mean            29271.194003        686.882199          3.463397
# std             19444.806226        184.811682          1.409661
# min               800.460000       -760.661236         -1.000000
# 25%             14177.540000        624.350000          3.000000
# ...

# %%
train['days_since_last_login'].replace(-999,0,inplace=True)

# %%
train.describe()
# Out:
#                 age  days_since_last_login  avg_time_spent  \
# count  36992.000000           36992.000000    36992.000000
# mean      37.118161              12.069096      243.472334
# std       15.867412               6.139792      398.289149
# min       10.000000               0.000000    -2814.109110
# 25%       23.000000               8.000000       60.102500
# 50%       37.000000              12.000000      161.765000
# 75%       51.000000              16.000000      356.515000
# max       64.000000              26.000000     3235.578521
#
#        avg_transaction_value  points_in_wallet  churn_risk_score
# count           36992.000000      36992.000000      36992.000000
# mean            29271.194003        686.882199          3.463397
# std             19444.806226        184.811682          1.409661
# min               800.460000       -760.661236         -1.000000
# 25%             14177.540000        624.350000          3.000000
# ...

# %%
sns.distplot(train['avg_time_spent'])
# Out:
# C:\Users\vikas\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='avg_time_spent', ylabel='Density'>

# %%
sns.heatmap(train.corr(),annot=True)
# Out:
# <AxesSubplot:>

# %%
train[train['churn_risk_score']==-1].index.tolist()
# Out:
# [23,
#  50,
#  62,
#  63,
#  85,
#  99,
#  116,
#  145,
#  175,
#  196,
#  280,
#  290,
#  328,
#  329,
#  336,
#  409,
#  520,
#  595,
#  603,
#  624,
#  634,
#  643,
#  650,
#  683,
#  796,
#  797,
#  824,
#  839,
#  843,
#  849,
#  856,
#  859,
#  889,
#  930,
#  978,
#  980,
#  981,
#  987,
#  992,
#  1045,
#  1140,
#  1142,
#  1225,
#  1281,
#  1291,
#  1312,
#  1313,
#  1334,
#  1340,
#  1391,
#  1435,
#  1489,
#  1496,
#  1499,
#  1522,
#  1562,
#  1577,
#  1612,
#  1636,
#  1671,
#  1681,
#  1712,
#  1713,
#  1729,
#  1775,
#  1779,
#  1797,
#  1803,
#  1839,
#  1881,
#  1895,
#  1940,
#  1942,
#  1994,
#  2012,
#  2030,
#  2085,
#  2196,
#  2200,
#  2203,
#  2207,
#  2247,
#  2263,
#  2279,
#  2363,
#  2436,
#  2501,
#  2536,
#  2537,
#  2573,
#  2588,
#  2589,
#  2786,
#  2806,
#  2864,
#  2937,
#  2976,
#  2990,
#  3000,
#  3002,
#  3013,
#  3018,
#  3024,
#  3036,
#  3061,
#  3062,
#  3066,
#  3074,
#  3075,
#  3081,
#  3082,
#  3134,
#  3235,
#  3271,
#  3282,
#  3283,
# ...

# %%
sns.boxplot(x=train['avg_time_spent'])
# Out:
# <AxesSubplot:xlabel='avg_time_spent'>

# %%
a= train.avg_time_spent.abs()

# %%
sns.boxplot(a)
# Out:
# C:\Users\vikas\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='avg_time_spent'>

# %%
sns.boxplot(x=train['points_in_wallet'])
# Out:
# <AxesSubplot:xlabel='points_in_wallet'>

# %%
# Convert feedback column into good and bad
# churn_rusk_score forward or backward fill
# medium_opeeration and joind through referral "?" replace mode
# avg timespent first apply abs >1000
# days_since_last_login forward and backward fill

# %%
train.groupby(by = ['joining_date']).count()
# Out:
#               customer_id  Name  age  gender  security_no  region_category  \
# joining_date
# 2015-01-01             26    26   26      26           26               26
# 2015-01-02             29    29   29      29           29               29
# 2015-01-03             37    37   37      37           37               37
# 2015-01-04             35    35   35      35           35               35
# 2015-01-05             47    47   47      47           47               47
# ...                   ...   ...  ...     ...          ...              ...
# 2017-12-27             33    33   33      33           33               33
# 2017-12-28             25    25   25      25           25               25
# 2017-12-29             37    37   37      37           37               37
# 2017-12-30             31    31   31      31           31               31
# 2017-12-31             41    41   41      41           41               41
#
# ...

# %%
import datetime as dt
train['joining_date'] = pd.to_datetime(train['joining_date'])
train['year']=train['joining_date'].dt.year

# %%
train.groupby(by = ['year']).count()
# Out:
#       customer_id   Name    age  gender  security_no  region_category  \
# year
# 2015        12297  12297  12297   12297        12297            12297
# 2016        12155  12155  12155   12155        12155            12155
# 2017        12540  12540  12540   12540        12540            12540
#
#       membership_category  joining_date  joined_through_referral  referral_id  \
# year
# 2015                12297         12297                    12297        12297
# 2016                12155         12155                    12155        12155
# 2017                12540         12540                    12540        12540
#
#       ...  avg_time_spent  avg_transaction_value  avg_frequency_login_days  \
# year  ...
# 2015  ...           12297                  12297                     12297
# 2016  ...           12155                  12155                     12155
# 2017  ...           12540                  12540                     12540
#
# ...

# %%
train.head()
# Out:
#                             customer_id              Name  age gender  \
# 0      fffe4300490044003600300030003800   Pattie Morrisey   18      F
# 1  fffe43004900440032003100300035003700       Traci Peery   32      F
# 2      fffe4300490044003100390032003600   Merideth Mcmeen   44      F
# 3  fffe43004900440036003000330031003600  Eufemia Cardwell   37      M
# 4  fffe43004900440031003900350030003600      Meghan Kosak   31      F
#
#   security_no region_category  membership_category joining_date  \
# 0     XW0DQ7H         Village  Platinum Membership   2017-08-17
# 1     5K0N3X1            City   Premium Membership   2017-08-28
# 2     1F2TCL3            Town        No Membership   2016-11-11
# 3     VJGJ33N            City        No Membership   2016-10-29
# 4     SVZXCWB            City        No Membership   2017-09-12
#
#   joined_through_referral referral_id  ... avg_transaction_value  \
# 0                      No    xxxxxxxx  ...              53005.25
# ...

# %%
train.shape
# Out:
# (36992, 26)

# %%
train.describe()
# Out:
#                 age  days_since_last_login  avg_time_spent  \
# count  36992.000000           36992.000000    36992.000000
# mean      37.118161              12.069096      243.472334
# std       15.867412               6.139792      398.289149
# min       10.000000               0.000000    -2814.109110
# 25%       23.000000               8.000000       60.102500
# 50%       37.000000              12.000000      161.765000
# 75%       51.000000              16.000000      356.515000
# max       64.000000              26.000000     3235.578521
#
#        avg_transaction_value  points_in_wallet  churn_risk_score          year
# count           36992.000000      36992.000000      36992.000000  36992.000000
# mean            29271.194003        686.882199          3.463397   2016.006569
# std             19444.806226        184.811682          1.409661      0.819384
# min               800.460000       -760.661236         -1.000000   2015.000000
# ...

# %%
train['avg_time_spent']=train['avg_time_spent'].abs()

# %%
sns.boxplot(train['avg_time_spent'])
# Out:
# C:\Users\vikas\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='avg_time_spent'>

# %%
##which ML models sensitive to outliers
#naive bayes---not sensitive
#SVM ----not
#linear---sensitive
#logistic----sensitive
#DT---not
#ensemble models----not
#knn---not sensitive
#kmeans---sensitive
#pca----very sensitive
#neural networks----sensitive

# %%
plt.hist(train.avg_time_spent,bins=20)
plt.show()

# %%
IQR=train.avg_time_spent.quantile(0.75)-train.avg_time_spent.quantile(0.25)

# %%
lower_bridge=train['avg_time_spent'].quantile(0.25)-(IQR*1.5)
upper_bridge=train['avg_time_spent'].quantile(0.75)+(IQR*1.5)
print(lower_bridge),print(upper_bridge)
# Out:
# -435.66374999999994
# 927.2462499999999
# (None, None)

# %%
lower_bridge=train['avg_time_spent'].quantile(0.25)-(IQR*3)
upper_bridge=train['avg_time_spent'].quantile(0.75)+(IQR*3)
print(lower_bridge),print(upper_bridge)
# Out:
# -946.7549999999999
# 1438.3374999999999
# (None, None)

# %%
train.loc[train['avg_time_spent']>=1438,'avg_time_spent']=1438

# %%
plt.hist(train.avg_time_spent,bins=20)
plt.show()

# %%
sns.boxplot(x=train['avg_time_spent'])
# Out:
# <AxesSubplot:xlabel='avg_time_spent'>

# %%
train['points_in_wallet']=train['points_in_wallet'].abs()

# %%
plt.hist(train.points_in_wallet,bins=20)
plt.show()

# %%
sns.boxplot(train['points_in_wallet'])
# Out:
# C:\Users\vikas\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='points_in_wallet'>

# %%
train['churn_risk_score'].replace(-1,np.NaN,inplace=True)

# %%
train['churn_risk_score'].fillna(method='ffill',axis=0,inplace=True)

# %%
train['churn_risk_score'].value_counts()
# Out:
# 3.0    10751
# 4.0    10527
# 5.0    10153
# 2.0     2828
# 1.0     2733
# Name: churn_risk_score, dtype: int64

# %%
train.head()
# Out:
#                             customer_id              Name  age gender  \
# 0      fffe4300490044003600300030003800   Pattie Morrisey   18      F
# 1  fffe43004900440032003100300035003700       Traci Peery   32      F
# 2      fffe4300490044003100390032003600   Merideth Mcmeen   44      F
# 3  fffe43004900440036003000330031003600  Eufemia Cardwell   37      M
# 4  fffe43004900440031003900350030003600      Meghan Kosak   31      F
#
#   security_no region_category  membership_category joining_date  \
# 0     XW0DQ7H         Village  Platinum Membership   2017-08-17
# 1     5K0N3X1            City   Premium Membership   2017-08-28
# 2     1F2TCL3            Town        No Membership   2016-11-11
# 3     VJGJ33N            City        No Membership   2016-10-29
# 4     SVZXCWB            City        No Membership   2017-09-12
#
#   joined_through_referral referral_id  ... avg_transaction_value  \
# 0                      No    xxxxxxxx  ...              53005.25
# ...

# %%
train.describe()
# Out:
#                 age  days_since_last_login  avg_time_spent  \
# count  36992.000000           36992.000000    36992.000000
# mean      37.118161              12.069096      310.786154
# std       15.867412               6.139792      327.417740
# min       10.000000               0.000000        1.837399
# 25%       23.000000               8.000000       75.427500
# 50%       37.000000              12.000000      186.175000
# 75%       51.000000              16.000000      416.155000
# max       64.000000              26.000000     1438.000000
#
#        avg_transaction_value  points_in_wallet  churn_risk_score          year
# count           36992.000000      36992.000000      36992.000000  36992.000000
# mean            29271.194003        688.104635          3.609294   2016.006569
# std             19444.806226        180.206764          1.176097      0.819384
# min               800.460000          0.788907          1.000000   2015.000000
# ...

# %%
plt.hist(train.avg_transaction_value,bins=20)
plt.show()

# %%
sns.boxplot(train['avg_transaction_value'])
# Out:
# C:\Users\vikas\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='avg_transaction_value'>

# %%
IQR=train.avg_transaction_value.quantile(0.75)-train.avg_transaction_value.quantile(0.25)

# %%
lower_bridge=train['avg_transaction_value'].quantile(0.25)-(IQR*1.5)
upper_bridge=train['avg_transaction_value'].quantile(0.75)+(IQR*1.5)
print(lower_bridge),print(upper_bridge)
# Out:
# -25838.814999999995
# 80871.465
# (None, None)

# %%
lower_bridge=train['avg_transaction_value'].quantile(0.25)-(IQR*3)
upper_bridge=train['avg_transaction_value'].quantile(0.75)+(IQR*3)
print(lower_bridge),print(upper_bridge)
# Out:
# -65855.17
# 120887.81999999999
# (None, None)

# %%
train.loc[train['avg_transaction_value']>=80871,'avg_transaction_value']=80871

# %%
plt.hist(train.avg_transaction_value,bins=20)
plt.hist(train.avg_transaction_value,bins=20)
plt.show()

# %%
train.head()
# Out:
#                             customer_id              Name  age gender  \
# 0      fffe4300490044003600300030003800   Pattie Morrisey   18      F
# 1  fffe43004900440032003100300035003700       Traci Peery   32      F
# 2      fffe4300490044003100390032003600   Merideth Mcmeen   44      F
# 3  fffe43004900440036003000330031003600  Eufemia Cardwell   37      M
# 4  fffe43004900440031003900350030003600      Meghan Kosak   31      F
#
#   security_no region_category  membership_category joining_date  \
# 0     XW0DQ7H         Village  Platinum Membership   2017-08-17
# 1     5K0N3X1            City   Premium Membership   2017-08-28
# 2     1F2TCL3            Town        No Membership   2016-11-11
# 3     VJGJ33N            City        No Membership   2016-10-29
# 4     SVZXCWB            City        No Membership   2017-09-12
#
#   joined_through_referral referral_id  ... avg_transaction_value  \
# 0                      No    xxxxxxxx  ...              53005.25
# ...

# %%
train.shape
# Out:
# (36992, 26)

# %%
#labelEncoder
from sklearn.preprocessing import LabelEncoder
column = ['region_category','membership_category','joined_through_referral','preferred_offer_types','medium_of_operation', 'internet_option','complaint_status','feedback']
le = LabelEncoder()
for col in column:
    train[col] = le.fit_transform(train[col])
    
train.head()
# Out:
#                             customer_id              Name  age gender  \
# 0      fffe4300490044003600300030003800   Pattie Morrisey   18      F
# 1  fffe43004900440032003100300035003700       Traci Peery   32      F
# 2      fffe4300490044003100390032003600   Merideth Mcmeen   44      F
# 3  fffe43004900440036003000330031003600  Eufemia Cardwell   37      M
# 4  fffe43004900440031003900350030003600      Meghan Kosak   31      F
#
#   security_no  region_category  membership_category joining_date  \
# 0     XW0DQ7H                2                    3   2017-08-17
# 1     5K0N3X1                0                    4   2017-08-28
# 2     1F2TCL3                1                    2   2016-11-11
# 3     VJGJ33N                0                    2   2016-10-29
# 4     SVZXCWB                0                    2   2017-09-12
#
#    joined_through_referral referral_id  ...  avg_transaction_value  \
# 0                        0    xxxxxxxx  ...               53005.25
# ...

# %%
train.columns
# Out:
# Index(['customer_id', 'Name', 'age', 'gender', 'security_no',
#        'region_category', 'membership_category', 'joining_date',
#        'joined_through_referral', 'referral_id', 'preferred_offer_types',
#        'medium_of_operation', 'internet_option', 'last_visit_time',
#        'days_since_last_login', 'avg_time_spent', 'avg_transaction_value',
#        'avg_frequency_login_days', 'points_in_wallet', 'used_special_discount',
#        'offer_application_preference', 'past_complaint', 'complaint_status',
#        'feedback', 'churn_risk_score', 'year'],
#       dtype='object')

# %%
train.drop(labels=['Name','security_no','referral_id'],axis=1,inplace=True)

# %%
train.head()
# Out:
#                             customer_id  age gender  region_category  \
# 0      fffe4300490044003600300030003800   18      F                2
# 1  fffe43004900440032003100300035003700   32      F                0
# 2      fffe4300490044003100390032003600   44      F                1
# 3  fffe43004900440036003000330031003600   37      M                0
# 4  fffe43004900440031003900350030003600   31      F                0
#
#    membership_category joining_date  joined_through_referral  \
# 0                    3   2017-08-17                        0
# 1                    4   2017-08-28                        1
# 2                    2   2016-11-11                        1
# 3                    2   2016-10-29                        1
# 4                    2   2017-09-12                        0
#
#    preferred_offer_types  medium_of_operation  internet_option  ...  \
# 0                      1                    0                2  ...
# ...

# %%
cat_cal = ['gender','used_special_discount','offer_application_preference','past_complaint']
train = pd.get_dummies(data=train, columns=cat_cal, drop_first=True)

# %%
train.head()
# Out:
#                             customer_id  age  region_category  \
# 0      fffe4300490044003600300030003800   18                2
# 1  fffe43004900440032003100300035003700   32                0
# 2      fffe4300490044003100390032003600   44                1
# 3  fffe43004900440036003000330031003600   37                0
# 4  fffe43004900440031003900350030003600   31                0
#
#    membership_category joining_date  joined_through_referral  \
# 0                    3   2017-08-17                        0
# 1                    4   2017-08-28                        1
# 2                    2   2016-11-11                        1
# 3                    2   2016-10-29                        1
# 4                    2   2017-09-12                        0
#
#    preferred_offer_types  medium_of_operation  internet_option  \
# 0                      1                    0                2
# 1                      1                    1                1
# ...

# %%
train.dtypes
# Out:
# customer_id                                 object
# age                                          int64
# region_category                              int32
# membership_category                          int32
# joining_date                        datetime64[ns]
# joined_through_referral                      int32
# preferred_offer_types                        int32
# medium_of_operation                          int32
# internet_option                              int32
# last_visit_time                             object
# days_since_last_login                        int64
# avg_time_spent                             float64
# avg_transaction_value                      float64
# avg_frequency_login_days                    object
# points_in_wallet                           float64
# complaint_status                             int32
# feedback                                     int32
# churn_risk_score                           float64
# ...

# %%
train.drop(labels=['last_visit_time'],axis=1,inplace=True)

# %%
train['month']=train['joining_date'].dt.month
train['day']=train['joining_date'].dt.day

# %%
train.dtypes
# Out:
# customer_id                                 object
# age                                          int64
# region_category                              int32
# membership_category                          int32
# joining_date                        datetime64[ns]
# joined_through_referral                      int32
# preferred_offer_types                        int32
# medium_of_operation                          int32
# internet_option                              int32
# days_since_last_login                        int64
# avg_time_spent                             float64
# avg_transaction_value                      float64
# avg_frequency_login_days                    object
# points_in_wallet                           float64
# complaint_status                             int32
# feedback                                     int32
# churn_risk_score                           float64
# year                                         int64
# ...

# %%
train.drop(columns='joining_date',axis=1,inplace=True)

# %%
train['avg_frequency_login_days']=pd.to_numeric(train.avg_frequency_login_days,errors='coerce')

# %%
train.dtypes
# Out:
# customer_id                          object
# age                                   int64
# region_category                       int32
# membership_category                   int32
# joined_through_referral               int32
# preferred_offer_types                 int32
# medium_of_operation                   int32
# internet_option                       int32
# days_since_last_login                 int64
# avg_time_spent                      float64
# avg_transaction_value               float64
# avg_frequency_login_days            float64
# points_in_wallet                    float64
# complaint_status                      int32
# feedback                              int32
# churn_risk_score                    float64
# year                                  int64
# gender_M                              uint8
# gender_Unknown                        uint8
# used_special_discount_Yes             uint8
# offer_application_preference_Yes      uint8
# ...

# %%
train.set_index(['customer_id'],inplace=True,append=True)

# %%
train.head()
# Out:
#                                         age  region_category  \
#   customer_id
# 0 fffe4300490044003600300030003800       18                2
# 1 fffe43004900440032003100300035003700   32                0
# 2 fffe4300490044003100390032003600       44                1
# 3 fffe43004900440036003000330031003600   37                0
# 4 fffe43004900440031003900350030003600   31                0
#
#                                         membership_category  \
#   customer_id
# 0 fffe4300490044003600300030003800                        3
# 1 fffe43004900440032003100300035003700                    4
# 2 fffe4300490044003100390032003600                        2
# 3 fffe43004900440036003000330031003600                    2
# 4 fffe43004900440031003900350030003600                    2
#
#                                         joined_through_referral  \
#   customer_id
# 0 fffe4300490044003600300030003800                            0
# ...

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
num_col = ['age','days_since_last_login','avg_time_spent', 'avg_transaction_value', 'points_in_wallet']
train[num_col] = sc.fit_transform(train[num_col])

# %%
X = train.drop('churn_risk_score', axis=1)
y = train[['churn_risk_score']]

# %%
X.head()
# Out:
#                                              age  region_category  \
#   customer_id
# 0 fffe4300490044003600300030003800     -1.204886                2
# 1 fffe43004900440032003100300035003700 -0.322562                0
# 2 fffe4300490044003100390032003600      0.433715                1
# 3 fffe43004900440036003000330031003600 -0.007447                0
# 4 fffe43004900440031003900350030003600 -0.385585                0
#
#                                         membership_category  \
#   customer_id
# 0 fffe4300490044003600300030003800                        3
# 1 fffe43004900440032003100300035003700                    4
# 2 fffe4300490044003100390032003600                        2
# 3 fffe43004900440036003000330031003600                    2
# 4 fffe43004900440031003900350030003600                    2
#
#                                         joined_through_referral  \
#   customer_id
# 0 fffe4300490044003600300030003800                            0
# ...

# %%
from sklearn.model_selection  import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X,y, test_size=0.2, shuffle=True, stratify = y, random_state=123)

# %%
# from tpot import TPOTClassifier

# %%
# pipeline_optimizer = TPOTClassifier()

# %%
# pipeline_optimizer = TPOTClassifier(verbosity=2, max_time_mins=2)

# %%
from sklearn.linear_model import LogisticRegression

# %%
lr=LogisticRegression()

# %%
train[train['avg_frequency_login_days'].isnull()].index.tolist()
# Out:
# [(39, 'fffe43004900440034003100390036003500'),
#  (44, 'fffe4300490044003900300031003500'),
#  (45, 'fffe43004900440033003000360031003100'),
#  (48, 'fffe43004900440032003800320037003300'),
#  (50, 'fffe43004900440031003700370031003300'),
#  (61, 'fffe43004900440035003200330039003300'),
#  (64, 'fffe43004900440031003300370038003600'),
#  (69, 'fffe43004900440035003300380039003800'),
#  (75, 'fffe43004900440036003100360034003700'),
#  (87, 'fffe43004900440033003200360036003700'),
#  (98, 'fffe43004900440034003300380038003400'),
#  (100, 'fffe43004900440035003500320032003000'),
#  (105, 'fffe43004900440032003900330030003500'),
#  (115, 'fffe43004900440036003100310034003400'),
#  (183, 'fffe4300490044003300350035003900'),
#  (185, 'fffe43004900440033003700370038003500'),
#  (197, 'fffe4300490044003200340033003500'),
#  (198, 'fffe43004900440035003000310035003300'),
#  (206, 'fffe43004900440032003700360038003000'),
#  (217, 'fffe43004900440032003800320035003100'),
# ...

# %%
plt.hist(train.avg_frequency_login_days,bins=20)
plt.show()

# %%
sns.boxplot(train['avg_frequency_login_days'])
# Out:
# C:\Users\vikas\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='avg_frequency_login_days'>

# %%
train['avg_frequency_login_days'] = train['avg_frequency_login_days'].abs()

# %%
IQR=train.avg_frequency_login_days.quantile(0.75)-train.avg_frequency_login_days.quantile(0.25)

# %%
lower_bridge=train['avg_frequency_login_days'].quantile(0.25)-(IQR*1.5)
upper_bridge=train['avg_frequency_login_days'].quantile(0.75)+(IQR*1.5)
print(lower_bridge),print(upper_bridge)
# Out:
# -9.5
# 42.5
# (None, None)

# %%
lower_bridge=train['avg_frequency_login_days'].quantile(0.25)-(IQR*3)
upper_bridge=train['avg_frequency_login_days'].quantile(0.75)+(IQR*3)
print(lower_bridge),print(upper_bridge)
# Out:
# -29.0
# 61.0
# (None, None)

# %%
train.loc[train['avg_frequency_login_days']>=42.5,'avg_frequency_login_days']=42.5

# %%
train['avg_frequency_login_days'].fillna(train['avg_frequency_login_days'].mean(),inplace=True)

# %%
plt.hist(train.avg_frequency_login_days,bins=20)
plt.show()

# %%
X = train.drop('churn_risk_score', axis=1)
y = train[['churn_risk_score']]

# %%
X.isnull().sum()
# Out:
# age                                 0
# region_category                     0
# membership_category                 0
# joined_through_referral             0
# preferred_offer_types               0
# medium_of_operation                 0
# internet_option                     0
# days_since_last_login               0
# avg_time_spent                      0
# avg_transaction_value               0
# avg_frequency_login_days            0
# points_in_wallet                    0
# complaint_status                    0
# feedback                            0
# year                                0
# gender_M                            0
# gender_Unknown                      0
# used_special_discount_Yes           0
# offer_application_preference_Yes    0
# past_complaint_Yes                  0
# month                               0
# day                                 0
# dtype: int64

# %%
# from tpot import TPOTClassifier
# pipeline_optimizer = TPOTClassifier()
# Out:
# C:\Users\vikas\anaconda3\lib\site-packages\tpot\builtins\__init__.py:36: UserWarning: Warning: optional dependency `torch` is not available. - skipping import of NN models.
#   warnings.warn("Warning: optional dependency `torch` is not available. - skipping import of NN models.")

# %%
# pipeline_optimizer = TPOTClassifier(verbosity=2, max_time_mins=2)

# %%
y=y.values.ravel()
y
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-176-4ad56cbdf1de> in <module>
# ----> 1 y=y.values.ravel()
#       2 y
#
# AttributeError: 'numpy.ndarray' object has no attribute 'values'

# %%
X.head()
# Out:
#                                              age  region_category  \
#   customer_id
# 0 fffe4300490044003600300030003800     -1.204886                2
# 1 fffe43004900440032003100300035003700 -0.322562                0
# 2 fffe4300490044003100390032003600      0.433715                1
# 3 fffe43004900440036003000330031003600 -0.007447                0
# 4 fffe43004900440031003900350030003600 -0.385585                0
#
#                                         membership_category  \
#   customer_id
# 0 fffe4300490044003600300030003800                        3
# 1 fffe43004900440032003100300035003700                    4
# 2 fffe4300490044003100390032003600                        2
# 3 fffe43004900440036003000330031003600                    2
# 4 fffe43004900440031003900350030003600                    2
#
#                                         joined_through_referral  \
#   customer_id
# 0 fffe4300490044003600300030003800                            0
# ...

# %%
X[['avg_frequency_login_days','year','month','day']]=sc.fit_transform(X[['avg_frequency_login_days','year','month','day']])

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
Dt = DecisionTreeClassifier()
Dt.fit(X_train,y_train)
# Out:
# DecisionTreeClassifier()

# %%
dt_pred = Dt.predict(X_test)

# %%
clfreport = classification_report(dt_pred,y_test)
print(clfreport)
# Out:
#               precision    recall  f1-score   support
#
#          1.0       0.67      0.68      0.68       543
#          2.0       0.70      0.69      0.70       577
#          3.0       0.85      0.86      0.86      2132
#          4.0       0.65      0.62      0.63      2175
#          5.0       0.70      0.72      0.71      1972
#
#     accuracy                           0.73      7399
#    macro avg       0.71      0.71      0.71      7399
# weighted avg       0.73      0.73      0.73      7399

# %%
from sklearn.ensemble import RandomForestClassifier
rfc = RandomForestClassifier(n_estimators=150)
rfc.fit(X_train, y_train)
# Out:
# <ipython-input-175-3bb120a45cd8>:3: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   rfc.fit(X_train, y_train)
# RandomForestClassifier(n_estimators=150)

# %%
rfc_pred = rfc.predict(X_test)
print(classification_report(y_test,rfc_pred))
print(confusion_matrix(y_test,rfc_pred))
accuracy_score(y_test,rfc_pred)
# Out:
#               precision    recall  f1-score   support
#
#          1.0       0.68      0.71      0.70       547
#          2.0       0.73      0.69      0.70       566
#          3.0       0.87      0.88      0.88      2150
#          4.0       0.68      0.59      0.63      2105
#          5.0       0.71      0.80      0.76      2031
#
#     accuracy                           0.75      7399
#    macro avg       0.74      0.73      0.73      7399
# weighted avg       0.75      0.75      0.75      7399
#
# [[ 387  139    6    8    7]
#  [ 156  388    9    8    5]
#  [   7    3 1892  218   30]
#  [   4    3  232 1250  616]
#  [  11    2   26  359 1633]]
# 0.750101365049331

# %%
import xgboost as xgb

# %%
xg_model = xgb.XGBClassifier(random_state=1,
                             learning_rate=0.01)

# %%
xg_model.fit(X_train,y_train)
# Out:
# C:\Users\vikas\anaconda3\lib\site-packages\sklearn\utils\validation.py:73: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(**kwargs)
# XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#               colsample_bynode=1, colsample_bytree=1, gamma=0, gpu_id=-1,
#               importance_type='gain', interaction_constraints='',
#               learning_rate=0.01, max_delta_step=0, max_depth=6,
#               min_child_weight=1, missing=nan, monotone_constraints='()',
#               n_estimators=100, n_jobs=0, num_parallel_tree=1,
#               objective='multi:softprob', random_state=1, reg_alpha=0,
#               reg_lambda=1, scale_pos_weight=None, subsample=1,
#               tree_method='exact', validate_parameters=1, verbosity=None)

# %%
xg_pred = xg_model.predict(X_test)

# %%
print(accuracy_score(xg_pred,y_test))
# Out:
# 0.7632112447628058

# %%
test = pd.read_csv('D:/New folder/dataset/test.csv')

# %%
test.head()
# Out:
#                             customer_id              Name  age gender  \
# 0  fffe43004900440031003700300030003400    Alethia Meints   50      F
# 1  fffe43004900440031003900370037003300        Ming Lopez   41      M
# 2  fffe43004900440034003800360037003000  Carina Flannigan   31      F
# 3  fffe43004900440036003200370033003400      Kyung Wanner   64      M
# 4  fffe43004900440035003000370031003900       Enola Gatto   16      F
#
#   security_no region_category membership_category joining_date  \
# 0     OQJ1XAY         Village  Premium Membership   2015-11-02
# 1     OUQRPKO         Village     Gold Membership   2016-03-01
# 2     02J2RE7            Town   Silver Membership   2017-03-03
# 3     5YEQIF1            Town   Silver Membership   2017-08-18
# 4     100RYB5            Town       No Membership   2015-05-05
#
#   joined_through_referral referral_id  ... days_since_last_login  \
# 0                      No    xxxxxxxx  ...                    12
# ...

# %%
test.isnull().sum()
# Out:
# customer_id                        0
# Name                               0
# age                                0
# gender                             0
# security_no                        0
# region_category                 2948
# membership_category                0
# joining_date                       0
# joined_through_referral            0
# referral_id                        0
# preferred_offer_types            159
# medium_of_operation                0
# internet_option                    0
# last_visit_time                    0
# days_since_last_login              0
# avg_time_spent                     0
# avg_transaction_value              0
# avg_frequency_login_days           0
# points_in_wallet                1963
# used_special_discount              0
# offer_application_preference       0
# past_complaint                     0
# complaint_status                   0
# feedback                           0
# dtype: int64

# %%
test[test['region_category'].isnull()].index.tolist()
# Out:
# [7,
#  20,
#  21,
#  27,
#  29,
#  33,
#  49,
#  50,
#  51,
#  52,
#  57,
#  58,
#  60,
#  64,
#  73,
#  80,
#  86,
#  88,
#  95,
#  100,
#  103,
#  104,
#  110,
#  117,
#  129,
#  132,
#  138,
#  144,
#  147,
#  159,
#  163,
#  185,
#  194,
#  197,
#  199,
#  214,
#  222,
#  228,
#  234,
#  237,
#  245,
#  248,
#  249,
#  254,
#  255,
#  257,
#  266,
#  285,
#  293,
#  295,
#  297,
#  303,
#  304,
#  307,
#  323,
#  338,
#  345,
#  356,
#  357,
#  362,
#  365,
#  366,
#  376,
#  382,
#  384,
#  391,
#  401,
#  404,
#  429,
#  441,
#  443,
#  448,
#  465,
#  467,
#  472,
#  474,
#  477,
#  479,
#  484,
#  487,
#  490,
#  499,
#  501,
#  502,
#  503,
#  527,
#  533,
#  539,
#  548,
#  549,
#  561,
#  562,
#  575,
#  579,
#  598,
#  605,
#  619,
#  638,
#  644,
#  646,
#  681,
#  684,
#  688,
#  702,
#  704,
#  707,
#  708,
#  719,
#  720,
#  727,
#  738,
#  740,
#  745,
#  746,
#  749,
#  756,
#  772,
#  776,
#  779,
#  785,
#  790,
#  799,
#  803,
#  806,
#  808,
#  813,
#  816,
# ...

# %%
test['region_category'].fillna(method='ffill',axis=0,inplace=True)

# %%
test[test['preferred_offer_types'].isnull()].index.tolist()
# Out:
# [116,
#  139,
#  639,
#  1046,
#  1119,
#  1134,
#  1277,
#  1364,
#  1416,
#  1429,
#  1534,
#  1610,
#  1778,
#  2503,
#  2666,
#  2693,
#  2866,
#  2887,
#  2888,
#  3563,
#  3660,
#  3827,
#  3886,
#  4208,
#  4406,
#  4602,
#  4622,
#  4756,
#  4948,
#  5214,
#  5311,
#  5320,
#  5490,
#  5602,
#  5606,
#  5627,
#  5930,
#  6072,
#  6198,
#  6434,
#  6473,
#  6596,
#  6619,
#  6775,
#  6820,
#  7356,
#  7374,
#  7458,
#  7638,
#  7673,
#  7680,
#  7782,
#  7913,
#  7938,
#  8007,
#  8214,
#  8768,
#  9305,
#  9376,
#  9391,
#  9396,
#  9408,
#  9468,
#  9507,
#  9571,
#  9617,
#  9803,
#  9865,
#  10179,
#  10329,
#  10543,
#  10549,
#  10687,
#  10972,
#  11078,
#  11111,
#  11120,
#  11398,
#  11498,
#  11531,
#  11625,
#  11731,
#  11835,
#  11836,
#  11909,
#  11978,
#  12065,
#  12330,
#  12443,
#  12591,
#  12635,
#  12759,
#  12804,
#  12868,
#  12923,
#  13010,
#  13076,
#  13143,
#  13151,
#  13193,
#  13356,
#  13361,
#  13449,
#  13517,
#  13541,
#  13599,
#  13721,
# ...

# %%
test['preferred_offer_types'].fillna(method='ffill',axis=0,inplace=True)

# %%
test['points_in_wallet'].fillna(test['points_in_wallet'].mean(),inplace=True)

# %%
test.isnull().sum()
# Out:
# customer_id                     0
# Name                            0
# age                             0
# gender                          0
# security_no                     0
# region_category                 0
# membership_category             0
# joining_date                    0
# joined_through_referral         0
# referral_id                     0
# preferred_offer_types           0
# medium_of_operation             0
# internet_option                 0
# last_visit_time                 0
# days_since_last_login           0
# avg_time_spent                  0
# avg_transaction_value           0
# avg_frequency_login_days        0
# points_in_wallet                0
# used_special_discount           0
# offer_application_preference    0
# past_complaint                  0
# complaint_status                0
# feedback                        0
# dtype: int64

# %%
test.describe()
# Out:
#                 age  days_since_last_login  avg_time_spent  \
# count  19919.000000           19919.000000    19919.000000
# mean      36.884432             -39.216527      244.134926
# std       15.917311             223.274420      403.910806
# min       10.000000            -999.000000    -2180.780796
# 25%       23.000000               8.000000       59.360000
# 50%       37.000000              12.000000      161.240000
# 75%       51.000000              16.000000      354.195000
# max       64.000000              26.000000     3350.060000
#
#        avg_transaction_value  points_in_wallet
# count           19919.000000      19919.000000
# mean            29318.122196        685.968794
# std             19507.775429        182.438697
# min               803.710000       -465.289977
# 25%             14236.200000        624.480000
# 50%             27564.050000        685.968794
# 75%             40969.400000        757.855000
# max             99995.030000       2019.671602

# %%
test['days_since_last_login'].replace(-999,0,inplace=True)

# %%
test['avg_time_spent']=test['avg_time_spent'].abs()

# %%
sns.boxplot(test['avg_time_spent'])
# Out:
# C:\Users\vikas\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='avg_time_spent'>

# %%
plt.hist(train.avg_time_spent,bins=20)
plt.show()

# %%
IQR=train.avg_time_spent.quantile(0.75)-train.avg_time_spent.quantile(0.25)

# %%
lower_bridge=train['avg_time_spent'].quantile(0.25)-(IQR*1.5)
upper_bridge=train['avg_time_spent'].quantile(0.75)+(IQR*1.5)
print(lower_bridge),print(upper_bridge)

# %%
lower_bridge=train['avg_time_spent'].quantile(0.25)-(IQR*3)
upper_bridge=train['avg_time_spent'].quantile(0.75)+(IQR*3)
print(lower_bridge),print(upper_bridge)

# %%
plt.hist(train.avg_time_spent,bins=20)
